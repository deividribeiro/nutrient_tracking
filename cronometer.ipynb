# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, SymLogNorm
import pandas as pd
import seaborn as sns

# %%
bmr=1550

targets={
    'Alcohol (g)':0, 
    'Caffeine (mg)': 0, 
    'Water (g)': 472, 
    'B1 (Thiamine) (mg)': 1.2, 
    'B2 (Riboflavin) (mg)': 1.3, 
    'B3 (Niacin) (mg)': 16, 
    'B5 (Pantothenic Acid) (mg)': 5, 
    'B6 (Pyridoxine) (mg)': 1.3, 
    'B12 (Cobalamin) (µg)': 2.4, 
    'Folate (µg)': 400, 
    'Vitamin A (µg)': 900, 
    'Vitamin C (mg)': 90, 
    'Vitamin D (IU)': 600, 
    'Vitamin E (mg)': 15, 
    'Vitamin K (µg)': 120, 
    'Calcium (mg)': 1000, 
    'Copper (mg)': 0.9, 
    'Iron (mg)': 8, 
    'Magnesium (mg)': 420, 
    'Manganese (mg)': 2.3, 
    'Phosphorus (mg)': 700, 
    'Potassium (mg)': 3400, 
    'Selenium (µg)': 55, 
    'Sodium (mg)': 1500, 
    'Zinc (mg)': 11, 
    'Carbs (g)': 300, 
    'Fiber (g)': 38, 
    'Starch (g)': 0, 
    'Sugars (g)': 0, 
    'Added Sugars (g)': 0, 
    'Net Carbs (g)': 300, 
    'Fat (g)': 75, 
    'Cholesterol (mg)': 0, 
    'Monounsaturated (g)': 0, 
    'Polyunsaturated (g)': 0, 
    'Saturated (g)': 0, 
    'Trans-Fats (g)': 0, 
    'Omega-3 (g)': 1.6, 
    'Omega-6 (g)': 17, 
    'Cystine (g)': 0.6, 
    'Histidine (g)': 0.9, 
    'Isoleucine (g)': 1.3, 
    'Leucine (g)': 2.8, 
    'Lysine (g)': 2.5, 
    'Methionine (g)': 0.6, 
    'Phenylalanine (g)': 1.1, 
    'Protein (g)': 0, 
    'Threonine (g)': 1.3, 
    'Tryptophan (g)': 0.3, 
    'Tyrosine (g)': 1.1, 
    'Valine (g)': 1.6, 
}
target_df = pd.DataFrame.from_dict(targets, orient='index')

# %%
summary = pd.read_csv("dailysummary.csv")
exercises = pd.read_csv("exercises.csv")
servings = pd.read_csv("servings.csv")

# %%
daily_totals = servings.groupby('Day').sum()
# daily_totals = summary

# summary.iloc[7] is equal to servings.groupby("Day").sum().iloc[1]

# %%
differences = (daily_totals-target_df[0])/target_df[0]
#positive means I am above target, negative is below target. I need to replenish the negatives

# %%
fields_to_plot=[
 # 'Alcohol (g)',#
 # 'Caffeine (mg)',#
 # 'Water (g)',#
 'B1 (Thiamine) (mg)',
 'B2 (Riboflavin) (mg)',
 'B3 (Niacin) (mg)',
 'B5 (Pantothenic Acid) (mg)',
 'B6 (Pyridoxine) (mg)',
 'B12 (Cobalamin) (µg)',
 'Folate (µg)',
 'Vitamin A (µg)',
 'Vitamin C (mg)',
 'Vitamin D (IU)',
 'Vitamin E (mg)',
 'Vitamin K (µg)',
 'Calcium (mg)',
 'Copper (mg)',
 'Iron (mg)',
 'Magnesium (mg)',
 'Manganese (mg)',
 'Phosphorus (mg)',
 'Potassium (mg)',
 'Selenium (µg)',
 # 'Sodium (mg)',#
 # 'Zinc (mg)',#
 'Carbs (g)',
 'Fiber (g)',
 # 'Starch (g)',
 # 'Sugars (g)',
 # 'Added Sugars (g)',
 'Net Carbs (g)',
 'Fat (g)',
 # 'Cholesterol (mg)',
 # 'Monounsaturated (g)',
 # 'Polyunsaturated (g)',
 # 'Saturated (g)',
 # 'Trans-Fats (g)',
 'Omega-3 (g)',
 'Omega-6 (g)',
 'Cystine (g)',
 'Histidine (g)',
 'Isoleucine (g)',
 'Leucine (g)',
 'Lysine (g)',
 'Methionine (g)',
 'Phenylalanine (g)',
 # 'Protein (g)',
 'Threonine (g)',
 'Tryptophan (g)',
 'Tyrosine (g)',
 'Valine (g)']

# %%
differences
# Out:
#             Added Sugars (g)  Alcohol (g) Amount  B1 (Thiamine) (mg)  \
# Day
# 2025-01-31               inf          NaN    NaN           -0.158333
# 2025-02-01               inf          inf    NaN            0.958333
# 2025-02-02               inf          NaN    NaN           -0.383333
# 2025-02-03               inf          inf    NaN           -0.025000
# 2025-02-04               inf          inf    NaN            0.508333
# 2025-02-05               inf          inf    NaN            0.358333
# 2025-02-06               inf          inf    NaN            0.725000
# 2025-02-07               inf          inf    NaN            0.391667
# 2025-02-08               inf          NaN    NaN            0.058333
# 2025-02-09               inf          NaN    NaN            0.016667
# 2025-02-10               inf          inf    NaN           -0.241667
# 2025-02-11               inf          inf    NaN           -0.175000
# 2025-02-12               inf          NaN    NaN            0.291667
# 2025-02-13               inf          inf    NaN           -0.258333
# 2025-02-14               inf          inf    NaN           -0.358333
# 2025-02-15               inf          NaN    NaN           -0.650000
# 2025-02-16               inf          NaN    NaN           -0.766667
# 2025-02-17               inf          inf    NaN            0.083333
# 2025-02-18               inf          inf    NaN           -0.408333
# 2025-02-19               inf          inf    NaN            0.316667
# 2025-02-20               inf          inf    NaN            0.016667
# 2025-02-21               inf          inf    NaN            0.108333
# 2025-02-22               inf          NaN    NaN           -0.700000
# 2025-02-23               inf          NaN    NaN            0.150000
# 2025-02-24               inf          inf    NaN            0.941667
# 2025-02-25               inf          inf    NaN            1.100000
# 2025-02-26               inf          inf    NaN            0.866667
# 2025-02-27               inf          inf    NaN           -0.491667
# 2025-02-28               inf          inf    NaN            0.691667
# 2025-03-01               inf          inf    NaN            1.008333
# 2025-03-02               inf          NaN    NaN            1.000000
# 2025-03-03               inf          NaN    NaN           -0.575000
# 2025-03-04               inf          inf    NaN            0.416667
# 2025-03-05               inf          inf    NaN            0.416667
#
#             B12 (Cobalamin) (µg)  B2 (Riboflavin) (mg)  B3 (Niacin) (mg)  \
# Day
# 2025-01-31             -0.025000             -0.276923          0.113125
# 2025-02-01              2.187500              0.853846          0.803750
# 2025-02-02              1.704167             -0.030769         -0.112500
# 2025-02-03              1.720833             -0.069231         -0.023125
# 2025-02-04              1.770833              0.238462          0.332500
# 2025-02-05              2.033333              0.330769          0.283750
# 2025-02-06              2.070833              0.269231          0.337500
# 2025-02-07              1.804167              0.138462          0.310625
# 2025-02-08              1.729167             -0.176923          0.377500
# 2025-02-09              1.791667             -0.146154          1.254375
# 2025-02-10              1.537500             -0.030769          1.037500
# 2025-02-11              1.508333             -0.046154          0.960625
# 2025-02-12              1.150000             -0.061538          1.194375
# 2025-02-13              1.387500             -0.053846          0.093125
# 2025-02-14              3.216667              0.115385          0.403125
# 2025-02-23       -0.083889        0.979817        0.292000       -0.242167
# 2025-02-24        0.210000        0.734650        0.299333       -0.471833
# 2025-02-25        2.048667        0.734650        0.327333       -0.471833
# 2025-02-26        0.208000        0.797650        0.336667       -0.512083
# 2025-02-27       -0.399444        0.699583        0.238667       -0.680750
# 2025-02-28       -0.106333        0.688450        0.458667       -0.801750
# 2025-03-01        0.388889        0.986600        0.820000       -0.459083
# 2025-03-02        0.016111        0.937267        0.882667       -0.471500
# 2025-03-03       -0.538889        0.801133        0.100000       -0.936917
# 2025-03-04       -0.318667        0.729800        0.253333       -0.699083
# 2025-03-05       -0.318667        0.729800        0.253333       -0.699083
#
#             Water (g)  Zinc (mg)
# Day
# 2025-01-31   0.921907  -0.394545
# 2025-02-01   2.396801  -0.209091
# 2025-02-02   0.185233  -0.712727
# 2025-02-03   1.196398  -0.154545
# 2025-02-04   0.775953  -0.090000
# 2025-02-05   0.719915  -0.308182
# 2025-02-06   0.661525   0.241818
# 2025-02-07   1.307945   0.013636
# 2025-02-08   0.081504  -0.520000
# 2025-02-09   0.502309  -0.517273
# 2025-02-10   1.465678  -0.250909
# 2025-02-11   1.026292  -0.244545
# 2025-02-12   0.927373  -0.548182
# 2025-02-13   1.682712  -0.453636
# 2025-02-14   1.700487   0.383636
# 2025-02-15   0.763919  -0.577273
# 2025-02-16   1.956102  -0.739091
# 2025-02-17   0.862627  -0.306364
# 2025-02-18   1.406165  -0.573636
# 2025-02-19   4.958962  -0.315455
# 2025-02-20   4.658242  -0.445455
# 2025-02-21   4.562309  -0.334545
# 2025-02-22  -0.587606  -0.137273
# 2025-02-23   2.340742   0.202727
# 2025-02-24   1.990911   0.463636
# 2025-02-25   2.500911   0.483636
# 2025-02-26   1.914428   0.963636
# 2025-02-27   0.782309   0.083636
# 2025-02-28   1.465169  -0.111818
# 2025-03-01   1.410636   0.120909
# 2025-03-02   1.254110   0.118182
# 2025-03-03  -0.383814  -0.359091
# 2025-03-04   1.382182  -0.038182
# 2025-03-05   1.382182  -0.038182
#
# [34 rows x 56 columns]

# %%
# Assuming your DataFrame is called 'df' with date index and category columns
# Transpose the DataFrame to have categories on x-axis and dates on y-axis

df_transposed = differences[fields_to_plot]

# Create a custom colormap
cmap = sns.diverging_palette(10,130, as_cmap=True)

# Create the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df_transposed, cmap=cmap, center=0, 
            cbar_kws={'label': 'Value'})

# Customize the plot
plt.title('Heatmap of Categories over Time')
plt.xlabel('Categories')
plt.ylabel('Date')

# Rotate x-axis labels if there are many categories
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.savefig("figures/nutrients_raw.png")
plt.show()

# %%
df_transposed.mean()[df_transposed.mean()<0].keys()
# Out:
# Index(['Vitamin C (mg)', 'Vitamin K (µg)', 'Calcium (mg)', 'Copper (mg)',
#        'Magnesium (mg)', 'Potassium (mg)', 'Carbs (g)', 'Fiber (g)',
#        'Net Carbs (g)', 'Fat (g)', 'Omega-3 (g)', 'Omega-6 (g)'],
#       dtype='object')

# %%
df_transposed.mean().sort_values().keys()
# Out:
# Index(['Omega-6 (g)', 'Omega-3 (g)', 'Fiber (g)', 'Calcium (mg)',
#        'Magnesium (mg)', 'Potassium (mg)', 'Net Carbs (g)', 'Carbs (g)',
#        'Vitamin K (µg)', 'Fat (g)', 'Vitamin C (mg)', 'Copper (mg)',
#        'B2 (Riboflavin) (mg)', 'B1 (Thiamine) (mg)', 'Vitamin A (µg)',
#        'Manganese (mg)', 'Vitamin E (mg)', 'Phosphorus (mg)',
#        'B5 (Pantothenic Acid) (mg)', 'Iron (mg)', 'Cystine (g)',
#        'B3 (Niacin) (mg)', 'Selenium (µg)', 'Lysine (g)', 'Folate (µg)',
#        'Vitamin D (IU)', 'Leucine (g)', 'Threonine (g)', 'Tyrosine (g)',
#        'Valine (g)', 'Histidine (g)', 'B6 (Pyridoxine) (mg)', 'Isoleucine (g)',
#        'Methionine (g)', 'Tryptophan (g)', 'Phenylalanine (g)',
#        'B12 (Cobalamin) (µg)'],
#       dtype='object')

# %%
df_transposed.mean().sort_values()
# Out:
# Omega-6 (g)                  -0.563028
# Omega-3 (g)                  -0.555331
# Fiber (g)                    -0.487012
# Calcium (mg)                 -0.463912
# Magnesium (mg)               -0.435852
# Potassium (mg)               -0.400509
# Net Carbs (g)                -0.328802
# Carbs (g)                    -0.262127
# Vitamin K (µg)               -0.248748
# Fat (g)                      -0.168863
# Vitamin C (mg)               -0.128212
# Copper (mg)                  -0.058497
# B2 (Riboflavin) (mg)          0.071719
# B1 (Thiamine) (mg)            0.153922
# Vitamin A (µg)                0.243303
# Manganese (mg)                0.355243
# Vitamin E (mg)                0.362235
# Phosphorus (mg)               0.378291
# B5 (Pantothenic Acid) (mg)    0.425059
# Iron (mg)                     0.434044
# Cystine (g)                   0.544118
# B3 (Niacin) (mg)              0.593290
# Selenium (µg)                 0.642529
# Lysine (g)                    0.661882
# Folate (µg)                   0.669531
# Vitamin D (IU)                0.738275
# Leucine (g)                   0.742542
# Threonine (g)                 0.908824
# Tyrosine (g)                  0.909091
# Valine (g)                    0.986765
# Histidine (g)                 0.989869
# B6 (Pyridoxine) (mg)          1.167873
# Isoleucine (g)                1.185294
# Methionine (g)                1.394118
# Tryptophan (g)                1.478431
# Phenylalanine (g)             1.510695
# B12 (Cobalamin) (µg)          1.946078
# dtype: float64

# %%
df_transposed_clean = differences[fields_to_plot]

# Define the smallest value for the logarithmic scale (to avoid issues with 0)
linthresh = 1e-2  # Threshold below which the scale behaves linearly
vmin = df_transposed_clean.min().min()
vmax = df_transposed_clean.max().max()

# Create a symmetric logarithmic norm
norm = SymLogNorm(linthresh=linthresh, vmin=vmin, vmax=vmax)

# Create the heatmap
plt.figure(figsize=(12, 8))
heatmap = sns.heatmap(
    df_transposed_clean,
    cmap=cmap,
    norm=norm,
    cbar_kws={'label': 'Value (Symmetric Log Scale)'}
)

# Customize the colorbar ticks
colorbar = heatmap.collections[0].colorbar
colorbar.set_ticks([-vmax, -1, -linthresh, 0, linthresh, 1, vmax])
colorbar.set_ticklabels([f'{x:.1e}' for x in colorbar.get_ticks()])

# Customize the plot
plt.title('Heatmap of Categories over Time (Symmetric Log Scale)')
plt.xlabel('Categories')
plt.ylabel('Date')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig("figures/nutrients_log.png")
plt.show()
